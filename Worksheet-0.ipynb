# %%
# Name = Prashna Prajapati

#7.1 Warming Up Exercise
'''
Task 1. Classify Temperatures:
 1. Create empty lists for temperature classifications:
 (a) Cold: temperatures below 10°C.
 (b) Mild: temperatures between 10°C and 15°C.
 (c) Comfortable: temperatures between 15°C and 20°C.
 2. Iterate over the temperatures list and add each temperature to the appropriate cate
gory.
 3. Print the lists to verify the classifications.
'''

#list of temperatures
temperatures=[8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.0, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]

#Create empty lists for classifications
cold=[]
mild=[]
comfortable=[]

#Classify temperatures
for temp in temperatures:
    if temp<10:
        cold.append(temp)
    elif 10<=temp<=15:
        mild.append(temp)
    elif 15<=temp<=20:
        comfortable.append(temp)
print("cold temperatures:",cold)
print("mild temperatures:",mild)
print("comfortable temperatures:",comfortable)
# Out:
# cold temperatures: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# mild temperatures: [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.0, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# comfortable temperatures: [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]

# %%
'''
 Task 2. Based on Data- Answer all the Questions:
 1. How many times was it mild?
 (a) Hint: Count the number of items in the mild list and print the result.
 2. How many times was it comfortable?
 3. How many times was it cold?
 '''

#list of temperatures
temperatures=[8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.0, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]

#Create empty lists for classifications
cold=[]
mild=[]
comfortable=[]

#Classify temperatures
for temp in temperatures:
    if temp<10:
        cold.append(temp)
    elif 10<=temp<=15:
        mild.append(temp)
    elif 15<=temp<=20:
        comfortable.append(temp)
#Count the occurrences
print("Number of mild temperatures:", len(mild))
print("Number of comfortable temperatures:", len(comfortable))
print("Number of cold temperatures:", len(cold))
# Out:
# Number of mild temperatures: 16
# Number of comfortable temperatures: 16
# Number of cold temperatures: 16

# %%
'''
 Task 3. Convert Temperatures from Celsius to Fahrenheit
 Using the formula for temperature conversion, convert each reading from Celsius to Fahren
heit and store it in a new list called temperatures_fahrenheit.
 Formula:
 Fahrenheit = (Celsius × 9
 5 ) +32
 1. Iterate over the temperatures list and apply the formula to convert each temperature.
 2. Store the results in the new list.
 3. Print the converted Fahrenheit values
 '''

#list of temperatures
temperatures=[8.2, 17.4, 14.1, 7.9, 18.0, 13.5, 9.0, 17.8, 13.0, 8.5, 16.5, 12.9, 7.7, 17.2, 13.3, 8.4, 16.7, 14.0, 9.5, 18.3, 13.4, 8.1, 17.9, 14.2, 7.6, 17.0, 12.0, 8.0, 16.8, 13.7, 7.8, 17.5, 13.6, 8.7, 17.1, 13.8, 9.2, 18.1, 13.9, 8.3, 16.4, 12.7, 8.9, 18.2, 13.1, 7.8, 16.6, 12.5]

#Create empty lists for classifications
cold=[]
mild=[]
comfortable=[]

#Classify temperatures
for temp in temperatures:
    if temp<10:
        cold.append(temp)
    elif 10<=temp<=15:
        mild.append(temp)
    elif 15<=temp<=20:
        comfortable.append(temp)
# Convert temperatures to Fahrenheit
temperatures_fahrenheit = [(temp * 9/5) + 32 for temp in temperatures]

# Print Fahrenheit values
print("Temperatures in Fahrenheit:", temperatures_fahrenheit)
# Out:
# Temperatures in Fahrenheit: [46.76, 63.32, 57.379999999999995, 46.22, 64.4, 56.3, 48.2, 64.04, 55.4, 47.3, 61.7, 55.22, 45.86, 62.959999999999994, 55.94, 47.120000000000005, 62.059999999999995, 57.2, 49.1, 64.94, 56.120000000000005, 46.58, 64.22, 57.56, 45.68, 62.6, 53.6, 46.4, 62.24, 56.66, 46.04, 63.5, 56.48, 47.66, 62.78, 56.84, 48.56, 64.58, 57.02, 46.94, 61.519999999999996, 54.86, 48.02, 64.75999999999999, 55.58, 46.04, 61.88, 54.5]

# %%
'''
Task 4. Analyze Temperature Patterns by Time of Day:
 Scenario: Each day’s readings are grouped as:
 • Night (00-08),
 • Evening (08-16),
 • Day (16-24).
 1. Create empty lists for night, day, and evening temperatures.
 2. Iterate over the temperatures list, assigning values to each time-of-day list based on
 their position.
 3. Calculate and print the average day-time temperature.
 4. (Optional) Plot ”day vs. temperature” using matplotlib.
 '''

# Create empty lists for different times of the day
night = []
evening = []
day = []

# Assign values based on position
for i, temp in enumerate(temperatures):
    if i % 3 == 0:
        night.append(temp)
    elif i % 3 == 1:
        evening.append(temp)
    else:
        day.append(temp)

# Calculate average daytime temperature
average_day_temp = sum(day) / len(day)

# Print results
print("Night temperatures:", night)
print("Evening temperatures:", evening)
print("Day temperatures:", day)
print("Average day temperature:", average_day_temp)

# (Optional) Plot day vs. temperature
import matplotlib.pyplot as plt

plt.plot(range(1, len(day) + 1), day, marker='o', label='Day Temperatures')
plt.title('Daytime Temperatures')
plt.xlabel('Day Number')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.show()
# Out:
# Night temperatures: [8.2, 7.9, 9.0, 8.5, 7.7, 8.4, 9.5, 8.1, 7.6, 8.0, 7.8, 8.7, 9.2, 8.3, 8.9, 7.8]
# Evening temperatures: [17.4, 18.0, 17.8, 16.5, 17.2, 16.7, 18.3, 17.9, 17.0, 16.8, 17.5, 17.1, 18.1, 16.4, 18.2, 16.6]
# Day temperatures: [14.1, 13.5, 13.0, 12.9, 13.3, 14.0, 13.4, 14.2, 12.0, 13.7, 13.6, 13.8, 13.9, 12.7, 13.1, 12.5]
# Average day temperature: 13.35625

# %%
#8.1.1 Exercise- Recursion:

'''
Task 1- Sum of Nested Lists:
 Scenario: You have a list that contains numbers and other lists of numbers (nested lists).
 You want to find the total sum of all the numbers in this structure.
 Task:
 • Write a recursive function sum_nested_list(nested_list) that:
 1. Takes a nested list (a list that can contain numbers or other lists of numbers) as
 input.
 2. Sums all numbers at every depth level of the list, regardless of how deeply nested
 the numbers are.
 • Test the function with a sample nested list, such as
 nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
 The result should be the total sum of all the numbers.
 '''
def sum_nested_list(nested_list):
    
    total = 0
    for element in nested_list:
        if isinstance(element, list):  # Check if the element is a list
            total += sum_nested_list(element)  # Recursively sum the nested list
        else:
            total += element  # Add the number to the total
    return total

# Test the function with a sample nested list
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)

print("Sum of the nested list =", result)
# Out:
# Sum of the nested list = 36

# %%
'''
 Task 2- Generate All Permutations of a String:
 Scenario: Given a string,generate all possible permutations of its characters.This is useful for 
 understanding back tracking and recursive depth-firstsearch.
 Task:
 •Write a recursive function generate_permutations(s)that:
 –Takes a strings as input and returns a list of all unique permutations.
 •Test with strings like”abc”and”aab”.
  print(generate_permutations("abc"))
 # Should return [’abc’, ’acb’, ’bac’, ’bca’,’cab’, ’cba’]
 '''

def generate_permutations(s):
   
    # Base case: if the string has only one character, return it as the only permutation
    if len(s) == 1:
        return [s]
    
    # Recursive case: find permutations by fixing each character and permuting the rest
    permutations = []
    for i in range(len(s)):
        # Fix the current character
        char = s[i]
        # Permute the remaining characters
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            permutations.append(char + perm)
    
    # Return unique permutations (to handle duplicate characters)
    return list(set(permutations))

# Testing the function
print(generate_permutations("abc"))  
print(generate_permutations("aab"))
# Out:
# ['cab', 'acb', 'cba', 'abc', 'bca', 'bac']
# ['aba', 'aab', 'baa']

# %%
'''
Task 3. Directory Size Calculation:
 1. Write a recursive function calculate_directory_size(directory) where:
 • directory is a dictionary where keys represent file names (with values as sizes in
 KB) or directory names (with values as another dictionary representing a subdi
rectory).
 • The function should return the total size of the directory, including all nested
 subdirectories.
 2. Test the function with a sample directory structure.
 '''

def calculate_directory_size(directory):
   
    total_size = 0

    for key, value in directory.items():
        if isinstance(value, dict):  
            total_size += calculate_directory_size(value)  
        else:  
            total_size += value

    return total_size

# Sample directory structure
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

# Testing the function
total_size = calculate_directory_size(directory_structure)
print("Total directory size:", total_size, "KB")
# Out:
# Total directory size: 1400 KB

# %%
# 8.2.2 Exercises- Dynamic Programming:
'''
Task 1- Coin Change Problem:
Scenario: Given a set of coin denominations and a target amount, find the minimum number
 of coins needed to make the amount. If it’s not possible, return- 1.
 Task:
 1. Write a function min_coins(coins, amount) that:
 • Uses DP to calculate the minimum number of coins needed to make up the
 amount.
 2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
 [5, 5, 1]).
 '''

def min_coins(coins, amount):
   
    dp = [float('inf')] * (amount + 1)
    dp[0] = 0  

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    return dp[amount] if dp[amount] != float('inf') else -1

# Test the function
coins = [5, 5, 1]
amount = 11
result = min_coins(coins, amount)

print(f"Minimum coins required to make {amount} =", result)
# Out:
# Minimum coins required to make 11 = 3

# %%
'''
Task 2. Longest Common Subsequence(LCS):
 1.Writeafunctionlongest_common_subsequence(s1,s2)that:
 •UsesDPtofindthelengthoftheLCSoftwostringss1ands2.
 2. Testwithstringslike"abcde" and "ace";theLCSlengthshouldbe3 ("ace").
 '''

def longest_common_subsequence(s1, s2):
   
    m, n = len(s1), len(s2)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:  # Characters match
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:  # Characters don't match
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n] 
# Test the function
s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)

print(f"Length of LCS and '{s1}' and '{s2}'=", result)
# Out:
# Length of LCS and 'abcde' and 'ace'= 3

# %%
'''
Task 3. 0/1 Knapsack Problem:
1. Write a function knapsack(weights, values, capacity) that:
 • Uses DP to determine the maximum value that can be achieved within the given
 weight capacity.
 2. Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The re
sult should be 9.
'''

def knapsack(weights, values, capacity):
    
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:  # Item can be included
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:  # Item cannot be included
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]  

# Test the function
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
result = knapsack(weights, values, capacity)

print(f"Maximum value for capacity {capacity} =", result)
# Out:
# Maximum value for capacity 7 = 9
